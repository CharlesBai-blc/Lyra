# %%
import pandas as pd
from pathlib import Path

dir = Path(".")
df1 = pd.read_csv(dir / "songs_condensed.csv")

df_condensed = df1.iloc[::20]
df_condensed.to_csv(dir / "sample_dataset.csv", index=False)
